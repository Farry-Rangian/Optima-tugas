# %%
import random
import time

kocokKartu = "ya"
daftarKartuPertama = []
daftarKartuKedua = []
riwayat = []

print("Selamat datang di permainan Kartu")
print("Jika kartu kamu lebih dari 21 maka kamu menang")
print("tetapi jika kartu kamu kurang dari 21 maka kamu kalah")
print('')

while kocokKartu == "ya": 
    print("Kocok Kartu...")
    time.sleep(2)
    kartuPertama = random.randint(1,13)
    kartuKedua = random.randint(1,13)

    total = kartuPertama + kartuKedua

    print(f'Kartu Pertama = {kartuPertama}')
    daftarKartuPertama.append(kartuPertama)
    print(f'Kartu Kedua = {kartuKedua}')
    daftarKartuKedua.append(kartuKedua)
    
    if total < 21:
        print("Anda Kalah :(")
        riwayat.append("Kalah")
    else:
        print("Selamat Anda Menang :)")
        riwayat.append("Menang")

    print('')
    print(f'Jumlah Kartu = {total}')
    print(f'Riwayat Kartu Pertama : {daftarKartuPertama}')
    print(f'Riwayat Kartu Kedua : {daftarKartuKedua}')
    print(f'Riwayat Permainan : {riwayat}')    

    kocokKartu = input("Bermain lagi (ya/tidak)? ")
    print(' ')
# Out:
# Selamat datang di permainan Kartu
# Jika kartu kamu lebih dari 21 maka kamu menang
# tetapi jika kartu kamu kurang dari 21 maka kamu kalah
#
# Kocok Kartu...
# Kartu Pertama = 12
# Kartu Kedua = 4
# Anda Kalah :(
#
# Jumlah Kartu = 16
# Riwayat Kartu Pertama : [12]
# Riwayat Kartu Kedua : [4]
# Riwayat Permainan : ['Kalah']
# Bermain lagi (ya/tidak)? ya
#
# Kocok Kartu...
# Kartu Pertama = 6
# Kartu Kedua = 2
# Anda Kalah :(
#
# Jumlah Kartu = 8
# Riwayat Kartu Pertama : [12, 6]
# Riwayat Kartu Kedua : [4, 2]
# Riwayat Permainan : ['Kalah', 'Kalah']
# Bermain lagi (ya/tidak)? ya
#
# Kocok Kartu...
# Kartu Pertama = 10
# Kartu Kedua = 9
# Anda Kalah :(
#
# Jumlah Kartu = 19
# Riwayat Kartu Pertama : [12, 6, 10]
# Riwayat Kartu Kedua : [4, 2, 9]
# Riwayat Permainan : ['Kalah', 'Kalah', 'Kalah']
# Bermain lagi (ya/tidak)? ya
#
# Kocok Kartu...
# Kartu Pertama = 11
# Kartu Kedua = 3
# Anda Kalah :(
#
# Jumlah Kartu = 14
# Riwayat Kartu Pertama : [12, 6, 10, 11]
# Riwayat Kartu Kedua : [4, 2, 9, 3]
# Riwayat Permainan : ['Kalah', 'Kalah', 'Kalah', 'Kalah']
# Bermain lagi (ya/tidak)? ya
#
# Kocok Kartu...
# Kartu Pertama = 4
# Kartu Kedua = 6
# Anda Kalah :(
#
# Jumlah Kartu = 10
# Riwayat Kartu Pertama : [12, 6, 10, 11, 4]
# Riwayat Kartu Kedua : [4, 2, 9, 3, 6]
# Riwayat Permainan : ['Kalah', 'Kalah', 'Kalah', 'Kalah', 'Kalah']
# Bermain lagi (ya/tidak)? tidak
